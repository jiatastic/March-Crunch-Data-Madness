# %%
import requests
import time
import re
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
my_header = { 'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'}
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/qianxinhong/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import chromedriver_autoinstaller
chromedriver_autoinstaller.install()
# Out:
# '/Users/qianxinhong/opt/anaconda3/lib/python3.9/site-packages/chromedriver_autoinstaller/110/chromedriver'

# %%
data = []
browser = webdriver.Chrome()
for i in range(2003,2023):
    page = f'https://basketball.realgm.com/ncaa/stats/{i}/Averages/Qualified/All/Season/All/points/desc/1/'
    browser.get(page)
    page_source = browser.page_source
    soup = BeautifulSoup(page_source, 'lxml')
    PlayerName = soup.find_all('td')
    data.append(playerName)
print(data)

# %%
data = []
PlayerNmae = ""
browser = webdriver.Chrome()
for i in range(2003,2023):
    page = f'https://basketball.realgm.com/ncaa/stats/{i}/Averages/Qualified/All/Season/All/points/desc/1/'
    browser.get(page)
    page_source = browser.page_source
    table = soup.find("tbody")
    tr = table.findAll("tr")[0:]
    for i in tr:
        td = i.find_all("td")
        Allplayer.append([td[0].text,td[1].text,td[2].text,td[3].text,td[4].text,td[5].text,td[6].text,td[7].text,td[8].text
                          ,td[9].text,td[10].text,td[11].text,td[12].text,td[13].text,td[14].text,td[15].text,td[16].text,td[17].text
                          ,td[18].text,td[19].text,td[20].text,td[21].text,td[22].text])

# %%
import sklearn
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df = pd.DataFrame(Allplayer, columns =['Number','Player','Team','GP','MPG','PPG','FGM','FGA','FG%','3PM','3PA',
                                       '3P%','FTM','FTA','FT%','ORB','DRB','RPG','APG','SPG','BPG','TOV','PF'], dtype = float)
# Out:
# /var/folders/7z/hykpmnd10057nvwjpjyrbpy80000gn/T/ipykernel_1236/3596812778.py:1: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised.
#   df = pd.DataFrame(Allplayer, columns =['Number','Player','Team','GP','MPG','PPG','FGM','FGA','FG%','3PM','3PA',

# %%
df
# Out:
#       Number            Player  Team    GP   MPG   PPG  FGM   FGA    FG%  3PM  \
# 0        1.0        Peter Kiss    BU  27.0  35.7  25.2  9.1  20.0  0.456  1.9
# 1        2.0     Darius McGhee   LIB  33.0  33.6  24.6  8.4  18.3  0.456  4.3
# 2        3.0     Antoine Davis   UDM  29.0  37.0  23.9  8.2  19.1  0.429  3.9
# 3        4.0     Keegan Murray    UI  35.0  31.9  23.5  8.8  15.8  0.554  1.9
# 4        5.0         Max Abmas   ORU  30.0  36.8  22.8  7.5  17.9  0.422  3.8
# ...      ...               ...   ...   ...   ...   ...  ...   ...    ...  ...
# 2095    96.0  Darrion Trammell   SEA  31.0  33.4  17.3  5.2  13.0  0.400  1.8
# 2096    97.0    Jamaree Bouyea   USF  34.0  36.2  17.3  6.4  13.7  0.470  2.1
# 2097    98.0    Paolo Banchero  DUKE  39.0  33.0  17.2  6.3  13.2  0.478  1.1
# 2098    99.0      Jalen Rucker  USMA  31.0  32.0  17.1  5.9  14.5  0.404  2.7
# 2099   100.0         Eral Penn   LIU  29.0  32.1  17.1  5.7  13.2  0.428  1.4
#
# ...

# %%
df.to_csv("df.csv")
